# %% [markdown]
# <a href="https://colab.research.google.com/github/uttarabahad/CodeInPlace2021-Stanford-/blob/main/Blurring_An_Image_(Code_In_Place_2021).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **AIM:** To blur a given sample image.
#
# **Name:** Uttara Bahad

# %%
#Importing Necessary Packages
from google.colab.patches import cv2_imshow
import cv2
#Reading the original Image
img = cv2.imread('sample1.png')

#Showing the original Image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=366x253 at 0x7FF64DFF9210>

# %%
#Blurring the image using GaussianBlur Function
blur_img = cv2.GaussianBlur(img, (11,11), sigmaX=40, sigmaY=30)

#Displaying the blurred Image
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=RGB size=366x253 at 0x7FF63E4109D0>
